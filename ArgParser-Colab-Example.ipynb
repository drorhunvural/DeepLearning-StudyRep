# %% [markdown]
# ##Arg_Parser Example for Google Colab

# %%
#Source: https://colab.research.google.com/github/anthony-agbay/introduction-to-python/blob/main/modules/introduction-argparse-pt1/introduction-argparse-pt1.ipynb#scrollTo=0jcIWtbFksKi

# %%
##### SCRIPT STARTS HERE #####
#!usr/bin/bash python
# %%writefile reading_details.py
import argparse

def arg_parser():
    """ Parse command line arguments

    Outputs:
        arguments {object} -- object containing command line arguments
    """
    
    parser = argparse.ArgumentParser()
    parser.add_argument("title", help="Title of the book you read")
    parser.add_argument("author", help="Author name of the book you read")
    parser.add_argument("readNum", help="Number of times you read the book", type=int)
    parser.add_argument("-d", "--description", help="Print out that you have no recent reading activity")
    
    return(parser.parse_args())

def main():
    args = arg_parser()
    
    print("I have read {} by {} {} times.".format(args.title, args.author, args.readNum))
    
    if args.description:
        print("The book was {}.".format(args.description))
        
if __name__ == "__main__":
    main()
# Out:
# Writing reading_details.py

# %%
# !python3 reading_details.py "Dune" "Frank Herbert" 5
# Out:
# I have read Dune by Frank Herbert 5 times.

# %%
# !python3 reading_details.py "The Paper Menagerie and Other Stories" "Ken Liu" 2 -d "amazing"
# Out:
# I have read The Paper Menagerie and Other Stories by Ken Liu 2 times.
# The book was amazing.
